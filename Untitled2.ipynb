# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import sys
from sklearn import metrics # for the evaluation
from settings import CORR_GROUP, SEED1, SEED2, SEED3
from keras.callbacks import EarlyStopping
import tensorflow as tf

# %%
def unique_cols(df):
    a = df.to_numpy() # df.values (pandas<0.24)
    return (a[0] == a).all(0)

# %%
def create_supervised_dataset(df, target, feats, n_in=1, n_out=1):
    cols, names = list(), list()
    n_vars = len(feats)
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df[feats].shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df[target].shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(1)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(1)]
    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names
    agg.dropna(inplace=True)
    return agg.values

# %%
def write_results(model_desc, res):
    with open('./results/rmse_results2.csv', 'a') as writer:
        writer.write(model_desc+","+",".join([f'{num:.3f}' for num in res])+'\n')

# %%
df = pd.read_csv("data/mongo_data.csv", index_col='ts')
df = df.drop('Unnamed: 0', 1)
df.index = pd.to_datetime(df.index)

df = df.loc[:,np.invert(unique_cols(df))]

# Average window
df_2 = df.groupby(np.arange(len(df))//60).mean()

scaler = MinMaxScaler()
d = scaler.fit_transform(df_2)
scaled_df = pd.DataFrame(d, columns=df_2.columns, index=df_2.index)

callback = EarlyStopping(monitor='val_loss', patience=3, min_delta=0.002)
history_window = 15
prediction_window = 1

model = None
# Out:
# C:\Users\pedro\AppData\Local\Temp\ipykernel_36092\1316949215.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df = df.drop('Unnamed: 0', 1)

# %%
model_type = "SimpleLSTM"

# %%
rmse_res = []
for k in CORR_GROUP:
    values = create_supervised_dataset(scaled_df, k, CORR_GROUP[k], n_in=history_window, n_out=prediction_window)
    len_values = values.shape[0]
    # split into train and test sets 
    n_train_seconds = int(0.7*len_values) #70% dos valores
    n_cv_seconds =  int(0.9*len_values) #20% dos valores
    train = values[:n_train_seconds, :]
    cv = values[n_train_seconds:n_cv_seconds, :]

    # split into input and outputs
    train_X, train_y = train[:, :-1], train[:, -1:]
    cv_X, cv_y = cv[:, :-1], cv[:, -1:]
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
    cv_X = cv_X.reshape((cv_X.shape[0], 1, cv_X.shape[1]))
    if model_type == 'SimpleLSTM':
        import SimpleLSTM
        model_cells = 10
        model = SimpleLSTM.create_model(model_cells, train_X.shape[2])
    if model is None:
        print("Error finding a model")
        break
    results = []
    for s in [SEED1, SEED2, SEED3]:
        tf.keras.utils.set_random_seed(s)
        model.fit(train_X, train_y, epochs=10, batch_size=72, validation_data=(cv_X, cv_y), shuffle=False, callbacks=[callback])

        #Test for the day after
        n_test_seconds =  int(0.1*len_values) #10% dos valores
        test = values[-n_test_seconds:, :]

        test_X, test_y = test[:, :-1], test[:, -1:]
        test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))
        # make a prediction
        yhat = model.predict(test_X)
        results.append(np.sqrt(metrics.mean_squared_error(test_y, yhat)))
    rmse_res.append(sum(results)/3)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0696 - val_loss: 0.0612
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0573 - val_loss: 0.0602
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0559 - val_loss: 0.0592
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0543 - val_loss: 0.0570
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0535 - val_loss: 0.0567
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0513 - val_loss: 0.0558
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0510 - val_loss: 0.0548
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0496 - val_loss: 0.0574
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0497 - val_loss: 0.0541
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0493 - val_loss: 0.0645
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0507 - val_loss: 0.0579
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0496 - val_loss: 0.0521
# Epoch 1/10
# 313/313 [==============================] - 2s 2ms/step - loss: 0.0480 - val_loss: 0.0294
# Epoch 2/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0368 - val_loss: 0.0261
# Epoch 3/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0337 - val_loss: 0.0250
# Epoch 4/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0318 - val_loss: 0.0237
# Epoch 5/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0308 - val_loss: 0.0229
# Epoch 6/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0300 - val_loss: 0.0223
# Epoch 7/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0295 - val_loss: 0.0219
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0291 - val_loss: 0.0216
# Epoch 2/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0289 - val_loss: 0.0214
# Epoch 3/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0286 - val_loss: 0.0212
# Epoch 4/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0282 - val_loss: 0.0207
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0279 - val_loss: 0.0205
# Epoch 2/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0276 - val_loss: 0.0202
# Epoch 3/10
# 313/313 [==============================] - 0s 2ms/step - loss: 0.0274 - val_loss: 0.0201
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0272 - val_loss: 0.0200
# Epoch 1/10
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0813 - val_loss: 0.0619
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0487 - val_loss: 0.0593
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0465 - val_loss: 0.0617
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0453 - val_loss: 0.0623
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0444 - val_loss: 0.0623
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0437 - val_loss: 0.0615
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0430 - val_loss: 0.0608
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0426 - val_loss: 0.0605
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0423 - val_loss: 0.0597
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0420 - val_loss: 0.0591
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0418 - val_loss: 0.0588
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0414 - val_loss: 0.0580
# Epoch 1/10
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0860 - val_loss: 0.0580
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0532 - val_loss: 0.0484
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0494 - val_loss: 0.0453
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0477 - val_loss: 0.0437
# Epoch 5/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0467 - val_loss: 0.0427
# Epoch 6/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0459 - val_loss: 0.0420
# Epoch 7/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0454 - val_loss: 0.0416
# Epoch 8/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0450 - val_loss: 0.0412
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0447 - val_loss: 0.0410
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0445 - val_loss: 0.0410
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0443 - val_loss: 0.0408
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0442 - val_loss: 0.0406
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0441 - val_loss: 0.0406
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0440 - val_loss: 0.0406
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0440 - val_loss: 0.0405
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0440 - val_loss: 0.0406
# Epoch 1/10
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0088 - val_loss: 0.1394
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0067 - val_loss: 0.1181
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0042 - val_loss: 0.1166
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0046 - val_loss: 0.1146
# Epoch 5/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.1143
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.1097
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.1067
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0070 - val_loss: 0.1047
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0055 - val_loss: 0.1026
# Epoch 5/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0058 - val_loss: 0.1060
# Epoch 6/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0049 - val_loss: 0.1064
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0054 - val_loss: 0.1052
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0047 - val_loss: 0.1048
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0053 - val_loss: 0.1065
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0057 - val_loss: 0.1069
# Epoch 1/10
# 313/313 [==============================] - 2s 3ms/step - loss: 0.0673 - val_loss: 0.0403
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0143 - val_loss: 0.0427
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0148 - val_loss: 0.0437
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0152 - val_loss: 0.0409
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0153 - val_loss: 0.0398
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0157 - val_loss: 0.0416
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0168 - val_loss: 0.0388
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0163 - val_loss: 0.0369
# Epoch 1/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0162 - val_loss: 0.0364
# Epoch 2/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0165 - val_loss: 0.0345
# Epoch 3/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0165 - val_loss: 0.0359
# Epoch 4/10
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0164 - val_loss: 0.0353

# %%
print(rmse_res)
# Out:
# [0.11500319364914091, 0.030943999997235447, 0.08280160130150306, 0.05204123461519639, 0.22946918508541425, 0.06302188405063386]

# %%
a = [0.11500319364914091, 0.030943999997235447, 0.08280160130150306, 0.05204123461519639, 0.22946918508541425, 0.06302188405063386]
