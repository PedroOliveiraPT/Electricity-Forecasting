# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
values = [' ', '[[[ True]]]', '[[[False]]]']

seaborn.relplot(data=df, x=df.index, y='F', hue='F AD', hue_order=values, aspect=1.61)
plt.show()

# %%
df = pd.read_csv('data/anomaly_detection_data.csv')
df.head()
# Out:
#                     ts          S_SUM     I_SUM  H_TDH_I_L3_N     U_L3_L1  \
# 0  2022-04-01 21:58:00  149017.136923  1.085000     46.546923  412.949231
# 1  2022-04-01 21:59:00  149258.717000  1.074167     46.591833  412.805500
# 2  2022-04-01 22:00:00  127528.309333  0.915500     56.362500  412.796833
# 3  2022-04-01 22:01:00  111254.214167  0.802778     64.105000  412.316667
# 4  2022-04-01 22:03:00  128511.155000  0.917500     55.588333  411.468333
#
#    H_TDH_I_L1_N  C_phi_L1          P_L2          P_L1          P_L3  ...  \
# 0     42.878462  0.975385  44133.665769  45966.841923  42012.821154  ...
# 1     43.020500  0.972500  44455.749000  45921.133167  41803.113667  ...
# 2     49.680833  0.968667  36472.175333  38625.150333  34207.254000  ...
# 3     54.510833  0.967500  29998.746944  33447.270000  28162.318611  ...
# 4     47.931667  0.975833  35287.885833  39903.917500  34497.498333  ...
#
#            S_L2          S_L1  H_TDH_U_L1_N      U_L1_N     ReacE_SUM  \
# ...

# %%
for i in ['P_SUM', 'U_L1_N', 'I_SUM', 'F', 'C_phi_L3']:
    print('Anomalies found with', i)
    print(df[df[i + ' AD'] == '[[[ True]]]'][i])
# Out:
# Anomalies found with P_SUM
# 15       131321.469167
# 16       127675.820667
# 17        95552.626000
# 18        86001.348167
# 19        69005.573833
#              ...
# 17651      5457.110667
# 17652      5468.159667
# 17653      5450.227000
# 17654      5451.161667
# 17655      5450.178833
# Name: P_SUM, Length: 9828, dtype: float64
# Anomalies found with U_L1_N
# Series([], Name: U_L1_N, dtype: float64)
# Anomalies found with I_SUM
# Series([], Name: I_SUM, dtype: float64)
# Anomalies found with F
# 34       50.016167
# 35       49.990000
# 37       49.976000
# 50       49.981525
# 54       50.012500
#            ...
# 17897    49.993404
# 17899    50.010833
# 17900    49.970000
# 17901    49.980000
# 17908    50.000833
# Name: F, Length: 4599, dtype: float64
# Anomalies found with C_phi_L3
# Series([], Name: C_phi_L3, dtype: float64)
